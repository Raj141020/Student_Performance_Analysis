# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Expanded_data_with_more_features.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0           0  female         NaN   bachelor's degree      standard     none
# 1           1  female     group C        some college      standard      NaN
# 2           2  female     group B     master's degree      standard     none
# 3           3    male     group A  associate's degree  free/reduced     none
# 4           4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
#   WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0            < 5         71            71            74
# 1         5 - 10         69            90            88
# 2            < 5         87            93            91
# 3         5 - 10         45            56            42
# 4         5 - 10         76            78            75

# %%
df.describe()
# Out:
#          Unnamed: 0    NrSiblings     MathScore  ReadingScore  WritingScore
# count  30641.000000  29069.000000  30641.000000  30641.000000  30641.000000
# mean     499.556607      2.145894     66.558402     69.377533     68.418622
# std      288.747894      1.458242     15.361616     14.758952     15.443525
# min        0.000000      0.000000      0.000000     10.000000      4.000000
# 25%      249.000000      1.000000     56.000000     59.000000     58.000000
# 50%      500.000000      2.000000     67.000000     70.000000     69.000000
# 75%      750.000000      3.000000     78.000000     80.000000     79.000000
# max      999.000000      7.000000    100.000000    100.000000    100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 0 to 30640
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           30641 non-null  int64
#  1   Gender               30641 non-null  object
#  2   EthnicGroup          28801 non-null  object
#  3   ParentEduc           28796 non-null  object
#  4   LunchType            30641 non-null  object
#  5   TestPrep             28811 non-null  object
#  6   ParentMaritalStatus  29451 non-null  object
#  7   PracticeSport        30010 non-null  object
#  8   IsFirstChild         29737 non-null  object
#  9   NrSiblings           29069 non-null  float64
#  10  TransportMeans       27507 non-null  object
#  11  WklyStudyHours       29686 non-null  object
#  12  MathScore            30641 non-null  int64
#  13  ReadingScore         30641 non-null  int64
#  14  WritingScore         30641 non-null  int64
# dtypes: float64(1), int64(4), object(10)
# memory usage: 3.5+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup            1840
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
df = df.drop("Unnamed: 0", axis = 1)

# %%
df.head(50)
# Out:
#     Gender EthnicGroup          ParentEduc     LunchType   TestPrep  \
# 0   female         NaN   bachelor's degree      standard       none
# 1   female     group C        some college      standard        NaN
# 2   female     group B     master's degree      standard       none
# 3     male     group A  associate's degree  free/reduced       none
# 4     male     group C        some college      standard       none
# 5   female     group B  associate's degree      standard       none
# 6   female     group B        some college      standard  completed
# 7     male     group B        some college  free/reduced       none
# 8     male     group D         high school  free/reduced  completed
# 9   female     group B         high school  free/reduced       none
# 10    male     group C  associate's degree      standard       none
# 11    male     group D  associate's degree      standard       none
# 12  female     group B         high school      standard       none
# 13    male     group A        some college      standard  completed
# 14  female     group A     master's degree      standard       none
# 15  female     group C    some high school      standard       none
# 16    male     group C         high school      standard        NaN
# 17  female     group B    some high school  free/reduced       none
# 18    male     group C     master's degree  free/reduced  completed
# 19  female     group C  associate's degree  free/reduced       none
# 20    male     group D         high school      standard       none
# 21  female     group B        some college  free/reduced  completed
# 22    male     group D                 NaN      standard       none
# 23  female     group C    some high school      standard       none
# 24    male     group D                 NaN  free/reduced  completed
# 25    male     group A     master's degree  free/reduced       none
# 26    male     group B        some college      standard       none
# 27  female     group C   bachelor's degree      standard       none
# 28    male     group C         high school      standard       none
# 29  female     group D        some college      standard       none
# 30  female     group B        some college      standard       none
# 31  female     group E     master's degree  free/reduced       none
# 32    male         NaN        some college      standard       none
# 33    male     group E        some college      standard       none
# 34    male     group E  associate's degree      standard  completed
# 35  female     group D  associate's degree      standard       none
# 36  female     group D    some high school  free/reduced       none
# 37  female     group D  associate's degree  free/reduced  completed
# 38    male     group B  associate's degree  free/reduced       none
# 39    male     group C  associate's degree  free/reduced       none
# 40  female     group C  associate's degree      standard       none
# 41    male     group B        some college  free/reduced        NaN
# 42  female     group E  associate's degree  free/reduced       none
# 43    male     group B  associate's degree      standard       none
# 44  female     group C         high school      standard       none
# 45    male     group C         high school      standard  completed
# 46    male     group E        some college      standard       none
# 47    male         NaN  associate's degree  free/reduced  completed
# 48    male     group C        some college      standard       none
# 49    male     group D         high school      standard       none
#
#    ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0              married     regularly          yes         3.0     school_bus
# 1              married     sometimes          yes         0.0            NaN
# 2               single     sometimes          yes         4.0     school_bus
# 3              married         never           no         1.0            NaN
# 4              married     sometimes          yes         0.0     school_bus
# 5              married     regularly          yes         1.0     school_bus
# 6              widowed         never           no         1.0        private
# 7              married     sometimes          yes         1.0        private
# 8               single     sometimes           no         3.0        private
# 9              married     regularly          yes         NaN        private
# 10                 NaN     sometimes          yes         1.0        private
# 11            divorced     sometimes          yes         1.0     school_bus
# 12             married     regularly           no         1.0        private
# 13              single     sometimes          yes         1.0        private
# 14            divorced     sometimes          yes         2.0        private
# 15             married     sometimes          yes         0.0        private
# 16             married     sometimes          yes         0.0     school_bus
# 17            divorced     sometimes          yes         1.0     school_bus
# 18              single     sometimes           no         1.0        private
# 19             married         never          yes         3.0        private
# 20             married     sometimes          yes         5.0     school_bus
# 21             married     sometimes           no         2.0     school_bus
# 22             married         never          yes         5.0            NaN
# 23            divorced         never           no         3.0            NaN
# 24             married     sometimes          yes         2.0     school_bus
# 25             married     regularly          yes         1.0     school_bus
# 26             married     sometimes          yes         5.0     school_bus
# 27             married     sometimes          yes         4.0     school_bus
# 28             married     sometimes           no         1.0        private
# 29              single     sometimes          yes         0.0        private
# 30              single     sometimes          yes         5.0            NaN
# 31            divorced     sometimes          yes         1.0     school_bus
# 32             married     sometimes           no         2.0        private
# 33            divorced     sometimes          yes         0.0     school_bus
# 34              single     sometimes           no         NaN     school_bus
# 35             married     regularly           no         2.0        private
# 36             married     regularly          yes         1.0        private
# 37             married     regularly           no         1.0     school_bus
# 38              single     regularly          yes         5.0     school_bus
# 39             married         never          yes         0.0     school_bus
# 40            divorced     regularly           no         1.0            NaN
# 41             married     regularly          yes         3.0     school_bus
# 42             married     sometimes          yes         5.0     school_bus
# 43              single     sometimes          yes         3.0     school_bus
# 44             married     regularly          yes         NaN        private
# 45             married     sometimes          NaN         3.0            NaN
# 46             married           NaN           no         3.0     school_bus
# 47             married     regularly           no         2.0        private
# 48            divorced     regularly          yes         3.0     school_bus
# 49              single     sometimes          yes         2.0     school_bus
#
#    WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0             < 5         71            71            74
# 1          5 - 10         69            90            88
# 2             < 5         87            93            91
# 3          5 - 10         45            56            42
# 4          5 - 10         76            78            75
# 5          5 - 10         73            84            79
# 6          5 - 10         85            93            89
# 7            > 10         41            43            39
# 8            > 10         65            64            68
# 9             < 5         37            59            50
# 10         5 - 10         58            54            52
# 11         5 - 10         40            52            43
# 12         5 - 10         66            82            74
# 13           > 10         80            73            71
# 14            < 5         48            53            58
# 15            NaN         69            75            78
# 16         5 - 10         88            89            86
# 17         5 - 10         18            32            28
# 18         5 - 10         46            42            47
# 19            < 5         50            56            58
# 20         5 - 10         66            69            63
# 21         5 - 10         65            75            70
# 22         5 - 10         42            53            51
# 23         5 - 10         66            71            71
# 24         5 - 10         74            71            80
# 25         5 - 10         75            76            76
# 26            < 5         66            53            53
# 27           > 10         69            70            76
# 28         5 - 10         70            70            65
# 29            < 5         66            72            72
# 30         5 - 10         63            65            61
# 31         5 - 10         56            73            66
# 32         5 - 10         40            42            38
# 33            NaN         97            87            82
# 34         5 - 10         81            81            79
# 35         5 - 10         76            82            85
# 36         5 - 10         51            64            60
# 37         5 - 10         77            91            90
# 38         5 - 10         58            56            58
# 39         5 - 10         53            60            52
# 40         5 - 10         59            74            69
# 41         5 - 10         60            65            67
# 42            < 5         48            55            52
# 43            < 5         63            53            55
# 44         5 - 10         67            72            77
# 45         5 - 10         82            84            82
# 46           > 10         54            55            48
# 47            < 5         76            68            68
# 48           > 10         56            45            43
# 49         5 - 10         88            78            75

# %%
df.tail(50)
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType   TestPrep  \
# 30591    male     group D        some college  free/reduced       none
# 30592    male     group E   bachelor's degree      standard       none
# 30593  female     group C                 NaN      standard       none
# 30594  female     group D        some college      standard  completed
# 30595    male     group D    some high school  free/reduced  completed
# 30596    male     group C   bachelor's degree      standard       none
# 30597    male     group C        some college  free/reduced       none
# 30598    male     group E                 NaN      standard  completed
# 30599  female     group D        some college      standard       none
# 30600  female     group E         high school      standard       none
# 30601  female     group C   bachelor's degree      standard       none
# 30602    male     group D        some college      standard       none
# 30603    male     group A         high school      standard       none
# 30604    male     group E    some high school      standard       none
# 30605  female     group E     master's degree      standard        NaN
# 30606    male     group D  associate's degree  free/reduced       none
# 30607    male     group C        some college      standard       none
# 30608  female     group C        some college      standard       none
# 30609  female     group E    some high school      standard       none
# 30610  female     group B                 NaN      standard  completed
# 30611  female     group D  associate's degree  free/reduced  completed
# 30612  female     group B         high school      standard       none
# 30613  female     group E   bachelor's degree  free/reduced  completed
# 30614    male     group D   bachelor's degree      standard       none
# 30615  female     group D        some college  free/reduced       none
# 30616    male     group C         high school      standard       none
# 30617  female     group C  associate's degree      standard       none
# 30618  female     group E         high school      standard  completed
# 30619  female     group D         high school  free/reduced  completed
# 30620    male     group C   bachelor's degree      standard       none
# 30621  female     group A   bachelor's degree      standard       none
# 30622    male     group A  associate's degree  free/reduced  completed
# 30623  female     group B                 NaN      standard  completed
# 30624  female     group B   bachelor's degree      standard  completed
# 30625  female         NaN    some high school  free/reduced  completed
# 30626  female     group C  associate's degree  free/reduced       none
# 30627  female     group A         high school      standard  completed
# 30628  female     group B                 NaN  free/reduced       none
# 30629  female     group D  associate's degree      standard  completed
# 30630    male     group B  associate's degree  free/reduced       none
# 30631    male     group E    some high school      standard       none
# 30632  female     group D        some college      standard       none
# 30633  female     group C     master's degree      standard  completed
# 30634    male     group A  associate's degree  free/reduced  completed
# 30635    male     group C        some college      standard       none
# 30636  female     group D         high school      standard       none
# 30637    male     group E         high school      standard       none
# 30638  female         NaN         high school  free/reduced  completed
# 30639  female     group D  associate's degree      standard  completed
# 30640    male     group B        some college      standard       none
#
#       ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 30591             married     regularly           no         2.0
# 30592             married     regularly           no         4.0
# 30593             married     sometimes           no         2.0
# 30594             married     regularly           no         3.0
# 30595             married     regularly           no         2.0
# 30596             married     regularly           no         NaN
# 30597            divorced     sometimes           no         4.0
# 30598            divorced     sometimes           no         3.0
# 30599            divorced     sometimes           no         1.0
# 30600            divorced     regularly           no         2.0
# 30601              single           NaN           no         1.0
# 30602             married     sometimes           no         NaN
# 30603              single     regularly           no         2.0
# 30604                 NaN     sometimes           no         1.0
# 30605             married     sometimes           no         2.0
# 30606             married     regularly           no         1.0
# 30607             married     regularly           no         1.0
# 30608             married     sometimes           no         2.0
# 30609             married         never           no         2.0
# 30610             married     regularly           no         4.0
# 30611              single     regularly           no         5.0
# 30612             married         never           no         3.0
# 30613            divorced     regularly           no         1.0
# 30614            divorced     sometimes           no         NaN
# 30615             married     sometimes           no         2.0
# 30616                 NaN         never           no         3.0
# 30617             married     sometimes           no         1.0
# 30618             married     sometimes           no         1.0
# 30619              single     sometimes           no         5.0
# 30620             married           NaN           no         4.0
# 30621              single     regularly           no         2.0
# 30622            divorced     regularly           no         3.0
# 30623             married     regularly           no         2.0
# 30624              single     regularly           no         1.0
# 30625              single     sometimes           no         3.0
# 30626             married     regularly           no         1.0
# 30627             married         never           no         NaN
# 30628              single     sometimes           no         1.0
# 30629             married     sometimes           no         2.0
# 30630             married     sometimes           no         4.0
# 30631             married     sometimes           no         3.0
# 30632             married     regularly           no         3.0
# 30633             married         never           no         2.0
# 30634                 NaN     sometimes           no         2.0
# 30635             married     regularly           no         2.0
# 30636              single     sometimes           no         2.0
# 30637              single     regularly           no         1.0
# 30638             married     sometimes           no         1.0
# 30639             married     regularly           no         3.0
# 30640             married         never           no         1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 30591        private         5 - 10         62            64            56
# 30592     school_bus            < 5         60            56            50
# 30593     school_bus            < 5         79            85            90
# 30594     school_bus            < 5         66            80            80
# 30595        private         5 - 10         59            54            55
# 30596            NaN         5 - 10         54            44            47
# 30597     school_bus         5 - 10         84            84            73
# 30598        private         5 - 10         86            83            76
# 30599        private         5 - 10         48            55            56
# 30600        private         5 - 10         56            66            65
# 30601     school_bus           > 10         59            65            65
# 30602        private            < 5         76            74            71
# 30603     school_bus         5 - 10         71            63            65
# 30604     school_bus         5 - 10         93            77            79
# 30605     school_bus         5 - 10        100           100           100
# 30606     school_bus         5 - 10         67            64            54
# 30607     school_bus            < 5         78            68            69
# 30608        private           > 10         73            72            75
# 30609        private           > 10         66            79            71
# 30610        private         5 - 10         74            84            84
# 30611     school_bus            NaN         52            66            73
# 30612     school_bus            < 5         61            87            78
# 30613        private            < 5         49            58            62
# 30614     school_bus         5 - 10         82            73            80
# 30615        private         5 - 10         65            89            82
# 30616        private            < 5         71            68            63
# 30617        private            < 5         48            65            58
# 30618     school_bus         5 - 10         75            80            80
# 30619     school_bus         5 - 10         39            51            49
# 30620        private         5 - 10         91            85            77
# 30621        private         5 - 10         66            80            78
# 30622        private         5 - 10         53            53            53
# 30623            NaN         5 - 10         75            87            87
# 30624        private         5 - 10         41            66            65
# 30625        private         5 - 10         47            65            68
# 30626     school_bus         5 - 10         61            79            76
# 30627     school_bus           > 10         58            77            82
# 30628     school_bus         5 - 10         55            63            63
# 30629     school_bus            NaN         67            63            72
# 30630        private         5 - 10         43            28            24
# 30631     school_bus            < 5         80            65            66
# 30632        private         5 - 10         82            88            97
# 30633     school_bus         5 - 10         84            99            99
# 30634     school_bus         5 - 10         65            60            60
# 30635     school_bus         5 - 10         58            53            49
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30638        private         5 - 10         61            70            67
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58

# %%
df['WklyStudyHours'] = df['WklyStudyHours'].str.replace('05-Oct','5-10')

# %%
df.head(50)
# Out:
#     Gender EthnicGroup          ParentEduc     LunchType   TestPrep  \
# 0   female         NaN   bachelor's degree      standard       none
# 1   female     group C        some college      standard        NaN
# 2   female     group B     master's degree      standard       none
# 3     male     group A  associate's degree  free/reduced       none
# 4     male     group C        some college      standard       none
# 5   female     group B  associate's degree      standard       none
# 6   female     group B        some college      standard  completed
# 7     male     group B        some college  free/reduced       none
# 8     male     group D         high school  free/reduced  completed
# 9   female     group B         high school  free/reduced       none
# 10    male     group C  associate's degree      standard       none
# 11    male     group D  associate's degree      standard       none
# 12  female     group B         high school      standard       none
# 13    male     group A        some college      standard  completed
# 14  female     group A     master's degree      standard       none
# 15  female     group C    some high school      standard       none
# 16    male     group C         high school      standard        NaN
# 17  female     group B    some high school  free/reduced       none
# 18    male     group C     master's degree  free/reduced  completed
# 19  female     group C  associate's degree  free/reduced       none
# 20    male     group D         high school      standard       none
# 21  female     group B        some college  free/reduced  completed
# 22    male     group D                 NaN      standard       none
# 23  female     group C    some high school      standard       none
# 24    male     group D                 NaN  free/reduced  completed
# 25    male     group A     master's degree  free/reduced       none
# 26    male     group B        some college      standard       none
# 27  female     group C   bachelor's degree      standard       none
# 28    male     group C         high school      standard       none
# 29  female     group D        some college      standard       none
# 30  female     group B        some college      standard       none
# 31  female     group E     master's degree  free/reduced       none
# 32    male         NaN        some college      standard       none
# 33    male     group E        some college      standard       none
# 34    male     group E  associate's degree      standard  completed
# 35  female     group D  associate's degree      standard       none
# 36  female     group D    some high school  free/reduced       none
# 37  female     group D  associate's degree  free/reduced  completed
# 38    male     group B  associate's degree  free/reduced       none
# 39    male     group C  associate's degree  free/reduced       none
# 40  female     group C  associate's degree      standard       none
# 41    male     group B        some college  free/reduced        NaN
# 42  female     group E  associate's degree  free/reduced       none
# 43    male     group B  associate's degree      standard       none
# 44  female     group C         high school      standard       none
# 45    male     group C         high school      standard  completed
# 46    male     group E        some college      standard       none
# 47    male         NaN  associate's degree  free/reduced  completed
# 48    male     group C        some college      standard       none
# 49    male     group D         high school      standard       none
#
#    ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0              married     regularly          yes         3.0     school_bus
# 1              married     sometimes          yes         0.0            NaN
# 2               single     sometimes          yes         4.0     school_bus
# 3              married         never           no         1.0            NaN
# 4              married     sometimes          yes         0.0     school_bus
# 5              married     regularly          yes         1.0     school_bus
# 6              widowed         never           no         1.0        private
# 7              married     sometimes          yes         1.0        private
# 8               single     sometimes           no         3.0        private
# 9              married     regularly          yes         NaN        private
# 10                 NaN     sometimes          yes         1.0        private
# 11            divorced     sometimes          yes         1.0     school_bus
# 12             married     regularly           no         1.0        private
# 13              single     sometimes          yes         1.0        private
# 14            divorced     sometimes          yes         2.0        private
# 15             married     sometimes          yes         0.0        private
# 16             married     sometimes          yes         0.0     school_bus
# 17            divorced     sometimes          yes         1.0     school_bus
# 18              single     sometimes           no         1.0        private
# 19             married         never          yes         3.0        private
# 20             married     sometimes          yes         5.0     school_bus
# 21             married     sometimes           no         2.0     school_bus
# 22             married         never          yes         5.0            NaN
# 23            divorced         never           no         3.0            NaN
# 24             married     sometimes          yes         2.0     school_bus
# 25             married     regularly          yes         1.0     school_bus
# 26             married     sometimes          yes         5.0     school_bus
# 27             married     sometimes          yes         4.0     school_bus
# 28             married     sometimes           no         1.0        private
# 29              single     sometimes          yes         0.0        private
# 30              single     sometimes          yes         5.0            NaN
# 31            divorced     sometimes          yes         1.0     school_bus
# 32             married     sometimes           no         2.0        private
# 33            divorced     sometimes          yes         0.0     school_bus
# 34              single     sometimes           no         NaN     school_bus
# 35             married     regularly           no         2.0        private
# 36             married     regularly          yes         1.0        private
# 37             married     regularly           no         1.0     school_bus
# 38              single     regularly          yes         5.0     school_bus
# 39             married         never          yes         0.0     school_bus
# 40            divorced     regularly           no         1.0            NaN
# 41             married     regularly          yes         3.0     school_bus
# 42             married     sometimes          yes         5.0     school_bus
# 43              single     sometimes          yes         3.0     school_bus
# 44             married     regularly          yes         NaN        private
# 45             married     sometimes          NaN         3.0            NaN
# 46             married           NaN           no         3.0     school_bus
# 47             married     regularly           no         2.0        private
# 48            divorced     regularly          yes         3.0     school_bus
# 49              single     sometimes          yes         2.0     school_bus
#
#    WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0             < 5         71            71            74
# 1          5 - 10         69            90            88
# 2             < 5         87            93            91
# 3          5 - 10         45            56            42
# 4          5 - 10         76            78            75
# 5          5 - 10         73            84            79
# 6          5 - 10         85            93            89
# 7            > 10         41            43            39
# 8            > 10         65            64            68
# 9             < 5         37            59            50
# 10         5 - 10         58            54            52
# 11         5 - 10         40            52            43
# 12         5 - 10         66            82            74
# 13           > 10         80            73            71
# 14            < 5         48            53            58
# 15            NaN         69            75            78
# 16         5 - 10         88            89            86
# 17         5 - 10         18            32            28
# 18         5 - 10         46            42            47
# 19            < 5         50            56            58
# 20         5 - 10         66            69            63
# 21         5 - 10         65            75            70
# 22         5 - 10         42            53            51
# 23         5 - 10         66            71            71
# 24         5 - 10         74            71            80
# 25         5 - 10         75            76            76
# 26            < 5         66            53            53
# 27           > 10         69            70            76
# 28         5 - 10         70            70            65
# 29            < 5         66            72            72
# 30         5 - 10         63            65            61
# 31         5 - 10         56            73            66
# 32         5 - 10         40            42            38
# 33            NaN         97            87            82
# 34         5 - 10         81            81            79
# 35         5 - 10         76            82            85
# 36         5 - 10         51            64            60
# 37         5 - 10         77            91            90
# 38         5 - 10         58            56            58
# 39         5 - 10         53            60            52
# 40         5 - 10         59            74            69
# 41         5 - 10         60            65            67
# 42            < 5         48            55            52
# 43            < 5         63            53            55
# 44         5 - 10         67            72            77
# 45         5 - 10         82            84            82
# 46           > 10         54            55            48
# 47            < 5         76            68            68
# 48           > 10         56            45            43
# 49         5 - 10         88            78            75

# %%
plt.figure(figsize= (4,5))
ax = sns.countplot(data = df, x = "Gender")
ax.bar_label(ax.containers[0])
plt.title('Gender Distribution')
plt.show()

# %%
gb = df.groupby('ParentEduc').agg({'MathScore':'mean','ReadingScore':'mean','WritingScore':'mean'})

# %%
gb
# Out:
#                     MathScore  ReadingScore  WritingScore
# ParentEduc
# associate's degree  68.365586     71.124324     70.299099
# bachelor's degree   70.466627     73.062020     73.331069
# high school         64.435731     67.213997     65.421136
# master's degree     72.336134     75.832921     76.356896
# some college        66.390472     69.179708     68.501432
# some high school    62.584013     65.510785     63.632409

# %%
plt.figure(figsize= (8,8))
sns.heatmap(gb, annot = True)
plt.title('Parent Education')
plt.show()

# %%
gb1 = df.groupby('ParentMaritalStatus').agg({'MathScore':'mean','ReadingScore':'mean','WritingScore':'mean'})

# %%
gb1
# Out:
#                      MathScore  ReadingScore  WritingScore
# ParentMaritalStatus
# divorced             66.691197     69.655011     68.799146
# married              66.657326     69.389575     68.420981
# single               66.165704     69.157250     68.174440
# widowed              67.368866     69.651438     68.563452

# %%
plt.figure(figsize= (8,8))
sns.heatmap(gb1, annot = True)
plt.title('Parent Marital Status')
plt.show()

# %%
sns.boxplot(data = df, x = 'MathScore')
plt.show()

# %%
sns.boxplot(data = df, x = 'WritingScore')
plt.show()

# %%
print(df['EthnicGroup'].unique())
# Out:
# [nan 'group C' 'group B' 'group A' 'group D' 'group E']

# %%
groupA = df.loc[(df['EthnicGroup'] == 'group A')].count()

# %%
groupA
# Out:
# Gender                 2219
# EthnicGroup            2219
# ParentEduc             2078
# LunchType              2219
# TestPrep               2081
# ParentMaritalStatus    2121
# PracticeSport          2167
# IsFirstChild           2168
# NrSiblings             2096
# TransportMeans         1999
# WklyStudyHours         2146
# MathScore              2219
# ReadingScore           2219
# WritingScore           2219
# dtype: int64

# %%
groupB = df.loc[(df['EthnicGroup'] == 'group B')].count()
groupB
# Out:
# Gender                 5826
# EthnicGroup            5826
# ParentEduc             5470
# LunchType              5826
# TestPrep               5488
# ParentMaritalStatus    5605
# PracticeSport          5704
# IsFirstChild           5649
# NrSiblings             5546
# TransportMeans         5238
# WklyStudyHours         5642
# MathScore              5826
# ReadingScore           5826
# WritingScore           5826
# dtype: int64

# %%
groupC = df.loc[(df['EthnicGroup'] == 'group C')].count()
groupC
# Out:
# Gender                 9212
# EthnicGroup            9212
# ParentEduc             8652
# LunchType              9212
# TestPrep               8652
# ParentMaritalStatus    8858
# PracticeSport          9050
# IsFirstChild           8929
# NrSiblings             8763
# TransportMeans         8280
# WklyStudyHours         8933
# MathScore              9212
# ReadingScore           9212
# WritingScore           9212
# dtype: int64

# %%
groupD = df.loc[(df['EthnicGroup'] == 'group D')].count()
groupD
# Out:
# Gender                 7503
# EthnicGroup            7503
# ParentEduc             7056
# LunchType              7503
# TestPrep               7070
# ParentMaritalStatus    7218
# PracticeSport          7343
# IsFirstChild           7285
# NrSiblings             7106
# TransportMeans         6713
# WklyStudyHours         7270
# MathScore              7503
# ReadingScore           7503
# WritingScore           7503
# dtype: int64

# %%
groupE = df.loc[(df['EthnicGroup'] == 'group E')].count()
groupE
# Out:
# Gender                 4041
# EthnicGroup            4041
# ParentEduc             3814
# LunchType              4041
# TestPrep               3804
# ParentMaritalStatus    3892
# PracticeSport          3954
# IsFirstChild           3918
# NrSiblings             3820
# TransportMeans         3624
# WklyStudyHours         3924
# MathScore              4041
# ReadingScore           4041
# WritingScore           4041
# dtype: int64

# %%
groupA = df.loc[(df['EthnicGroup'] == 'group A')].count()
groupB = df.loc[(df['EthnicGroup'] == 'group B')].count()
groupC = df.loc[(df['EthnicGroup'] == 'group C')].count()
groupD = df.loc[(df['EthnicGroup'] == 'group D')].count()
groupE = df.loc[(df['EthnicGroup'] == 'group E')].count()

# groupA['EthnicGroup']

mlist = [groupA['EthnicGroup'], groupB['EthnicGroup'], groupC['EthnicGroup'], groupD['EthnicGroup'], groupE['EthnicGroup']]
# plt.pie([mlist])

plt.pie(mlist, labels=['Group A', 'Group B', 'Group C', 'Group D', 'Group E'], autopct='%1.1f%%')
plt.title('Distribution of Ethenic Groups')
print(mlist)
plt.show()
# Out:
# [2219, 5826, 9212, 7503, 4041]

# %%
ax = sns.countplot(data = df, x = 'EthnicGroup')
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '9212'),
#  Text(0, 0, '5826'),
#  Text(0, 0, '2219'),
#  Text(0, 0, '7503'),
#  Text(0, 0, '4041')]

# %%
df_filtered = df[df["EthnicGroup"] == "group C"]
df_filtered
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType   TestPrep  \
# 1      female     group C        some college      standard        NaN
# 4        male     group C        some college      standard       none
# 10       male     group C  associate's degree      standard       none
# 15     female     group C    some high school      standard       none
# 16       male     group C         high school      standard        NaN
# ...       ...         ...                 ...           ...        ...
# 30617  female     group C  associate's degree      standard       none
# 30620    male     group C   bachelor's degree      standard       none
# 30626  female     group C  associate's degree  free/reduced       none
# 30633  female     group C     master's degree      standard  completed
# 30635    male     group C        some college      standard       none
#
#       ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 1                 married     sometimes          yes         0.0
# 4                 married     sometimes          yes         0.0
# 10                    NaN     sometimes          yes         1.0
# 15                married     sometimes          yes         0.0
# 16                married     sometimes          yes         0.0
# ...                   ...           ...          ...         ...
# 30617             married     sometimes           no         1.0
# 30620             married           NaN           no         4.0
# 30626             married     regularly           no         1.0
# 30633             married         never           no         2.0
# 30635             married     regularly           no         2.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 1                NaN         5 - 10         69            90            88
# 4         school_bus         5 - 10         76            78            75
# 10           private         5 - 10         58            54            52
# 15           private            NaN         69            75            78
# 16        school_bus         5 - 10         88            89            86
# ...              ...            ...        ...           ...           ...
# 30617        private            < 5         48            65            58
# 30620        private         5 - 10         91            85            77
# 30626     school_bus         5 - 10         61            79            76
# 30633     school_bus         5 - 10         84            99            99
# 30635     school_bus         5 - 10         58            53            49
#
# [9212 rows x 14 columns]

# %%
df_filtered = df[(df["EthnicGroup"] == "group C") & (df["ParentMaritalStatus"] == "married")]
df_filtered
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType   TestPrep  \
# 1      female     group C        some college      standard        NaN
# 4        male     group C        some college      standard       none
# 15     female     group C    some high school      standard       none
# 16       male     group C         high school      standard        NaN
# 19     female     group C  associate's degree  free/reduced       none
# ...       ...         ...                 ...           ...        ...
# 30617  female     group C  associate's degree      standard       none
# 30620    male     group C   bachelor's degree      standard       none
# 30626  female     group C  associate's degree  free/reduced       none
# 30633  female     group C     master's degree      standard  completed
# 30635    male     group C        some college      standard       none
#
#       ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 1                 married     sometimes          yes         0.0
# 4                 married     sometimes          yes         0.0
# 15                married     sometimes          yes         0.0
# 16                married     sometimes          yes         0.0
# 19                married         never          yes         3.0
# ...                   ...           ...          ...         ...
# 30617             married     sometimes           no         1.0
# 30620             married           NaN           no         4.0
# 30626             married     regularly           no         1.0
# 30633             married         never           no         2.0
# 30635             married     regularly           no         2.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 1                NaN         5 - 10         69            90            88
# 4         school_bus         5 - 10         76            78            75
# 15           private            NaN         69            75            78
# 16        school_bus         5 - 10         88            89            86
# 19           private            < 5         50            56            58
# ...              ...            ...        ...           ...           ...
# 30617        private            < 5         48            65            58
# 30620        private         5 - 10         91            85            77
# 30626     school_bus         5 - 10         61            79            76
# 30633     school_bus         5 - 10         84            99            99
# 30635     school_bus         5 - 10         58            53            49
#
# [5089 rows x 14 columns]
